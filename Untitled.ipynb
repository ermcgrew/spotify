# %%
import pandas as pd
df = pd.read_json('MyData/PlaylistCreated.json')

print(df.to_string())
# Out:
#                      timestamp_utc            context_time  message_client_platform                     message_playlist_uri
# 0 2022-05-04 13:25:25.736000+00:00 2022-05-04 13:25:25.736                        0  spotify:playlist:7mEOPt6zESQjWmzknYkG7p
# 1 2022-05-04 13:25:05.640000+00:00 2022-05-04 13:25:05.640                        0  spotify:playlist:5zMjQ3atlPtv6UypxlxsQ4

# %%
df
# Out:
#                      timestamp_utc            context_time  \
# 0 2022-05-04 13:25:25.736000+00:00 2022-05-04 13:25:25.736
# 1 2022-05-04 13:25:05.640000+00:00 2022-05-04 13:25:05.640
#
#    message_client_platform                     message_playlist_uri
# 0                        0  spotify:playlist:7mEOPt6zESQjWmzknYkG7p
# 1                        0  spotify:playlist:5zMjQ3atlPtv6UypxlxsQ4

# %%
df2 = pd.read_json('MyData/SearchQueries.json')
df2
# Out:
#    platform                     searchTime searchQuery  \
# 0    IPHONE  2022-02-08T15:50:51.522Z[UTC]       manes
# 1    IPHONE  2022-02-08T23:24:11.674Z[UTC]     upstate
# 2    IPHONE  2022-02-09T21:15:47.966Z[UTC]       lizzo
# 3    IPHONE  2022-02-16T02:49:53.238Z[UTC]      margar
# 4    IPHONE  2022-02-19T03:05:35.044Z[UTC]       visqu
# 5    IPHONE  2022-02-19T03:06:29.468Z[UTC]      mac de
# 6    IPHONE  2022-02-25T15:31:16.307Z[UTC]      orvill
# 7    IPHONE  2022-03-20T20:16:36.445Z[UTC]     wolfcat
# 8    IPHONE  2022-03-20T20:17:55.538Z[UTC]        vulf
# 9    IPHONE  2022-03-31T13:07:11.513Z[UTC]  bills bill
# 10   IPHONE  2022-04-07T01:03:18.500Z[UTC]     orville
# 11   IPHONE  2022-04-15T13:47:48.675Z[UTC]       lizzo
# 12   IPHONE  2022-04-23T15:38:07.269Z[UTC]     keep it
# 13           2022-05-01T00:44:22.017Z[UTC]          li
# 14           2022-05-01T00:44:22.149Z[UTC]          li
# 15           2022-05-01T00:44:22.367Z[UTC]         liz
# ...

# %%
df3 = pd.read_json('MyData/StreamingHistory0.json')
df3
# Out:
#                endTime              artistName  \
# 0     2021-04-30 18:52  Appointment Television
# 1     2021-05-04 15:25                 Quakers
# 2     2021-05-04 15:26          Charles Mingus
# 3     2021-05-04 15:26            Neneh Cherry
# 4     2021-05-04 15:26                  Jungle
# ...                ...                     ...
# 3068  2022-05-04 18:52                  Jungle
# 3069  2022-05-04 18:55                  Jungle
# 3070  2022-05-04 18:56                  Jungle
# 3071  2022-05-04 20:50                  Jungle
# 3072  2022-05-04 20:50                   Lizzo
#
#                                               trackName  msPlayed
# 0     Episode 292: Dream Muppet-casting and Ted Lass...   1535310
# 1                                             War Drums    149800
# 2     Oh Lord Don't Let Them Drop That Atomic Bomb o...      4540
# 3         What Reason Could I Give - Kim Hiorthøy Remix     50330
# ...

# %%
sum(df3['msPlayed'])/60000
# Out:
# 19367.64015
